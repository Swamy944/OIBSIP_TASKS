# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#importing dataset
data=pd.read_csv("/content/sample_data/car data.csv")

# %% [markdown]
# # **EDA**

# %%
data.head(10)
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0           ritz  2014           3.35           5.59       27000    Petrol
# 1            sx4  2013           4.75           9.54       43000    Diesel
# 2           ciaz  2017           7.25           9.85        6900    Petrol
# 3        wagon r  2011           2.85           4.15        5200    Petrol
# 4          swift  2014           4.60           6.87       42450    Diesel
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
# 6           ciaz  2015           6.75           8.12       18796    Petrol
# 7        s cross  2015           6.50           8.61       33429    Diesel
# 8           ciaz  2016           8.75           8.89       20273    Diesel
# 9           ciaz  2015           7.45           8.92       42367    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# ...

# %%
data.tail(10)
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 291     brio  2015           5.40           6.10       31427    Petrol
# 292     jazz  2016           6.40           8.40       12000    Petrol
# 293     city  2010           3.25           9.90       38000    Petrol
# 294    amaze  2014           3.75           6.80       33019    Petrol
# 295     city  2015           8.55          13.09       60076    Diesel
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 291       Dealer       Manual      0
# 292       Dealer       Manual      0
# 293       Dealer       Manual      0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Driven_kms     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Selling_type   301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
data.describe()
# Out:
#               Year  Selling_Price  Present_Price     Driven_kms       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.642584   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
data.shape
# Out:
# (301, 9)

# %%
data.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Driven_kms',
#        'Fuel_Type', 'Selling_type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %%
col_names=['Fuel_Type','Selling_type','Transmission','Owner']
for col in col_names:
    print(data[col].value_counts())
# Out:
# Petrol    239
# Diesel     60
# CNG         2
# Name: Fuel_Type, dtype: int64
# Dealer        195
# Individual    106
# Name: Selling_type, dtype: int64
# Manual       261
# Automatic     40
# Name: Transmission, dtype: int64
# 0    290
# 1     10
# 3      1
# Name: Owner, dtype: int64

# %% [markdown]
# # **convert categorical data into numerical data**

# %%
#transforming data into numerical values
from sklearn.preprocessing import OrdinalEncoder
ord_enc = OrdinalEncoder()
data["Fuel_Type"] = ord_enc.fit_transform(data[["Fuel_Type"]])
data["Selling_type"] = ord_enc.fit_transform(data[["Selling_type"]])
data["Present_Price"] = ord_enc.fit_transform(data[["Present_Price"]])
data["Transmission"] = ord_enc.fit_transform(data[["Transmission"]])
data["Owner"] = ord_enc.fit_transform(data[["Owner"]])

# %%
data
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms  Fuel_Type  \
# 0       ritz  2014           3.35           57.0       27000        2.0
# 1        sx4  2013           4.75          104.0       43000        1.0
# 2       ciaz  2017           7.25          106.0        6900        2.0
# 3    wagon r  2011           2.85           48.0        5200        2.0
# 4      swift  2014           4.60           73.0       42450        1.0
# ..       ...   ...            ...            ...         ...        ...
# 296     city  2016           9.50          115.0       33988        1.0
# 297     brio  2015           4.00           62.0       60000        2.0
# 298     city  2009           3.35          114.0       87934        2.0
# 299     city  2017          11.50          119.0        9000        1.0
# 300     brio  2016           5.30           62.0        5464        2.0
#
#      Selling_type  Transmission  Owner
# 0             0.0           1.0    0.0
# ...

# %% [markdown]
# # **Finding and removing the Outliers**

# %%
plt.figure(figsize = (15,5))
sns.boxplot(data=data)
plt.show()

# %%
Q1 = np.percentile(data['Driven_kms'], 25,
                   interpolation = 'midpoint')

Q3 = np.percentile(data['Driven_kms'], 75,
                   interpolation = 'midpoint')
IQR = Q3 - Q1

print("Old Shape: ", data.shape)

# Upper bound
upper = np.where(data['Driven_kms'] >= (Q3+1.5*IQR))
# Lower bound
lower = np.where(data['Driven_kms'] <= (Q1-1.5*IQR))

''' Removing the Outliers '''
data.drop(upper[0], inplace = True)
data.drop(lower[0], inplace = True)

print("New Shape: ", data.shape)
# Out:
# Old Shape:  (301, 9)
# New Shape:  (293, 9)

# %%
data.shape
# Out:
# (293, 9)

# %% [markdown]
# # **Data Visualization**

# %%
sns.distplot(data['Year'])
# Out:
# <Axes: xlabel='Year', ylabel='Density'>

# %%
sns.distplot(data['Selling_Price'])
plt.show()

# %%
sns.distplot(data['Driven_kms'])
plt.show()

# %%
sns.distplot(data['Present_Price'])
plt.show()

# %%
plt.figure(figsize=(10, 8))
cor = data.corr()
ax = sns.heatmap(cor,annot=True)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.show()

# %%
print(data['Fuel_Type'].value_counts())
print(data['Selling_type'].value_counts())
print(data['Transmission'].value_counts())
# Out:
# 2.0    234
# 1.0     57
# 0.0      2
# Name: Fuel_Type, dtype: int64
# 0.0    192
# 1.0    101
# Name: Selling_type, dtype: int64
# 1.0    258
# 0.0     35
# Name: Transmission, dtype: int64

# %%
X = data.drop(['Car_Name','Selling_Price'],axis=1)
Y = data['Selling_Price']

# %%
X
# Out:
#      Year  Present_Price  Driven_kms  Fuel_Type  Selling_type  Transmission  \
# 0    2014           57.0       27000        2.0           0.0           1.0
# 1    2013          104.0       43000        1.0           0.0           1.0
# 2    2017          106.0        6900        2.0           0.0           1.0
# 3    2011           48.0        5200        2.0           0.0           1.0
# 4    2014           73.0       42450        1.0           0.0           1.0
# ..    ...            ...         ...        ...           ...           ...
# 296  2016          115.0       33988        1.0           0.0           1.0
# 297  2015           62.0       60000        2.0           0.0           1.0
# 298  2009          114.0       87934        2.0           0.0           1.0
# 299  2017          119.0        9000        1.0           0.0           1.0
# 300  2016           62.0        5464        2.0           0.0           1.0
#
#      Owner
# 0      0.0
# 1      0.0
# 2      0.0
# ...

# %%
Y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 293, dtype: float64

# %%
#splitting the data into train and test data
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=13)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (234, 7)
# (59, 7)
# (234,)
# (59,)

# %% [markdown]
# # **Modelling the algorithms**

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors  import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn import metrics
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
def apply_model(model1):
    model = model1
    model.fit(X_train, Y_train)
    Y_pred = model.predict(X_test)
    mse=mean_squared_error(Y_pred,Y_test)
    mbe=mean_absolute_error(Y_test, Y_pred)

    r2=r2_score(Y_pred,Y_test)

    print ('Mean Square error is ', mse)
    print('Mean Absolute Error:', mbe )
    print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Y_test, Y_pred)))
    print ('R2 Score is', r2)

# %%
apply_model(LinearRegression())
# Out:
# Mean Square error is  19.349520767077742
# Mean Absolute Error: 2.194497643123618
# Root Mean Squared Error: 4.398809016890565
# R2 Score is 0.02544658630772456

# %%
apply_model(KNeighborsRegressor(n_neighbors=2))
# Out:
# Mean Square error is  43.97408474576271
# Mean Absolute Error: 3.8659322033898307
# Root Mean Squared Error: 6.63129585720338
# R2 Score is -4.41534565120212

# %%
apply_model(DecisionTreeRegressor(max_depth=8))
# Out:
# Mean Square error is  7.969234031217571
# Mean Absolute Error: 1.3018825665859566
# Root Mean Squared Error: 2.822983179407481
# R2 Score is 0.6596243576413682

# %%
from sklearn.ensemble import RandomForestRegressor
rf=(RandomForestRegressor(n_estimators=100,
                      random_state=3,
                      max_samples=0.5,
                      max_features=0.75,
                      max_depth=15))
rf.fit(X_train, Y_train)
Y_pred = rf.predict(X_test)
mse=mean_squared_error(Y_pred,Y_test)
mbe=mean_absolute_error(Y_test, Y_pred)
r2=r2_score(Y_pred,Y_test)

print('Mean Absolute Error:', mbe )
print ('Mean Square error is ', mse)
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Y_test, Y_pred)))
print ('R2 Score is', r2)
# Out:
# Mean Absolute Error: 1.152859322033898
# Mean Square error is  10.661735541864406
# Root Mean Squared Error: 3.265231315215571
# R2 Score is 0.43236099441202724

# %% [markdown]
# # **Best Algorithm is Random Forest Here**

# %%
# compare the actual output values for X_test with the predicted values
df1 = pd.DataFrame({'Actual': Y_test, 'Predicted': Y_pred})
df1.reset_index(inplace=True,drop=True)
df1
# Out:
#     Actual  Predicted
# 0    12.90     9.8081
# 1     6.10     5.6100
# 2     5.50     5.5020
# 3     1.45     1.4750
# 4    12.50     8.8786
# 5     0.10     0.2992
# 6     0.42     0.5405
# 7     3.00     2.9335
# 8     0.52     0.4080
# 9     7.50     7.6209
# 10    9.70     9.0802
# 11    5.75     5.5019
# 12    8.25     6.8040
# 13   11.75     9.7010
# 14    1.05     2.4040
# 15    4.75     5.9328
# 16    0.45     0.5628
# 17    0.20     0.3585
# 18    4.95     5.3061
# 19    6.40     7.5424
# 20    1.11     1.1235
# 21    7.45     6.6000
# 22    6.45     5.5845
# 23    1.10     1.1131
# 24    8.25     8.5396
# 25    5.11     5.3100
# 26    2.90     3.0800
# 27    0.72     0.7266
# 28    7.05     7.5276
# 29    6.00     7.3728
# 30    0.35     0.4041
# 31    3.10     3.5350
# 32    7.40     7.8584
# 33    6.50     8.1265
# 34    6.50     6.4775
# 35    0.51     0.5802
# 36    1.25     1.0480
# 37    2.90     3.2940
# 38   33.00    21.5015
# 39    2.75     3.2937
# ...

# %%
plt.figure(figsize=(10, 6))
plt.scatter(Y_test, Y_pred, alpha=0.5)
plt.xlabel('Actual Selling Price')
plt.ylabel('Predicted Selling Price')
plt.title('Actual vs. Predicted Selling Prices')
plt.show()

# %% [markdown]
# # **Pickle Dumping**

# %%
import pickle
pickle.dump(rf,open('rf models.pkl','wb'))
