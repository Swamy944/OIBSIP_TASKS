# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Importing the dataset**

# %%
df_sales=pd.read_csv('/content/sample_data/Advertising.csv')

# %%
df_sales
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %% [markdown]
# # **Data Preprocessing**

# %%
df_sales.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
df_sales.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]>

# %%
df_sales.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
df_sales.columns=['Unnamed','TV','Radio','Newspaper','Sales']

# %%
df_sales
# Out:
#      Unnamed     TV  Radio  Newspaper  Sales
# 0          1  230.1   37.8       69.2   22.1
# 1          2   44.5   39.3       45.1   10.4
# 2          3   17.2   45.9       69.3    9.3
# 3          4  151.5   41.3       58.5   18.5
# 4          5  180.8   10.8       58.4   12.9
# ..       ...    ...    ...        ...    ...
# 195      196   38.2    3.7       13.8    7.6
# 196      197   94.2    4.9        8.1    9.7
# 197      198  177.0    9.3        6.4   12.8
# 198      199  283.6   42.0       66.2   25.5
# 199      200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df=df_sales.drop('Unnamed',axis=1)

# %%
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %% [markdown]
# # **Data Visualization**

# %%
sns.histplot(df["TV"])
# Out:
# <Axes: xlabel='TV', ylabel='Count'>

# %%
sns.histplot(df["Radio"])
# Out:
# <Axes: xlabel='Radio', ylabel='Count'>

# %%
sns.histplot(df["Newspaper"])
# Out:
# <Axes: xlabel='Newspaper', ylabel='Count'>

# %%
corr=df.corr()
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # **Splitting data into train and test data**

# %%
x=df.iloc[:,:-1]
x
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y=df['Sales']
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %% [markdown]
# # **Machine Learning Algorithm - Logistic Regression**

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
lg=LinearRegression()
lg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
ypred=lg.predict(x_test)
ypred
# Out:
# array([14.73158651, 14.51118482, 17.3203314 , 12.08777819,  9.37338086,
#        19.42474223,  8.1490387 , 20.90012662, 14.20167829, 19.88658287,
#        16.58629324, 10.65678381, 20.60214848, 10.14506496, 14.25396354,
#        17.46819125,  5.69342606, 21.22564118, 20.59601135, 20.87364019,
#        18.77819712, 15.41722903,  7.57980834, 21.39122936, 12.06574923,
#        13.64753039, 13.46520525, 14.21923673, 21.29125039,  7.27535973,
#        11.09933057, 14.02376396,  7.15315958, 12.11334118,  8.70491688,
#         3.47354389, 23.73931707, 15.46104551, 12.80961478, 16.41550834,
#        18.29259859,  5.25781956, 18.8300862 ,  9.73182093, 15.46147178,
#         8.84044245, 13.46435154, 12.36759862, 15.43104739, 10.18282523,
#         8.7990519 , 11.66815759, 14.18518418, 12.51796341, 23.41170753,
#        17.40448554, 19.14401984, 13.92206255, 16.44228046, 14.94996807])

# %%
from sklearn.metrics import r2_score
r2_score(ypred,y_test)*100
# Out:
# 88.65694210361418

# %%
figsize=(30, 25)

ax1 = sns.histplot(df['Sales'], color="r", label="Actual Value")
sns.histplot(ypred,color="b", label="Fitted Values" , ax=ax1);

plt.title('Actual vs Fitted Values for Price')
plt.legend()
plt.show()

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# An 88.65% accuracy of linear regression model is good.We can conclude that the TV advertisement spending has an impact on the Sales with a positive correlation between the two variables. Radio advertisement spending also had a moderate positive correlation with Sales, while the correlation between Newspaper advertisement spending and Sales is weak.
